# %% [markdown]
# # Covid-19 Worldwide cases Analysis

# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Will check Data for analysis using pandas library**

# %%
covid = pd.read_csv('/kaggle/input/corona-virus-report/country_wise_latest.csv')
covid
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# **Checking top 10 countries with most deaths.**

# %%
covid.nlargest(10,'Deaths')
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
# 111          Mexico     395489   44022     303810    47657       4973
# 85            Italy     246286   35112     198593    12581        168
# 79            India    1480073   33408     951166   495499      44457
# 61           France     220352   30212      81212   108928       2551
# 157           Spain     272421   28432     150376    93613          0
# 132            Peru     389717   18418     272547    98752      13756
# 81             Iran     293606   15912     255144    22550       2434
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# ...

# %% [markdown]
# **Sameway for the less deaths.**

# %%
covid.nsmallest(10,'Deaths')
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 19          Bhutan         99       0         86      13          4
# 30        Cambodia        226       0        147      79          1
# 49        Dominica         18       0         18       0          0
# 55         Eritrea        265       0        191      74          2
# 59            Fiji         27       0         18       9          0
# 68       Greenland         14       0         13       1          1
# 69         Grenada         23       0         23       0          0
# 75        Holy See         12       0         12       0          0
# 94            Laos         20       0         19       1          0
# 114       Mongolia        289       0        222      67          1
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 19            0              1                 0.0                  86.87
# ...

# %% [markdown]
# **now checking null values in the dataset.**

# %%
covid.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# **country with max deaths**

# %%
covid.max()
# Out:
# Country/Region                   Zimbabwe
# Confirmed                         4290259
# Deaths                             148011
# Recovered                         1846641
# Active                            2816444
# New cases                           56336
# New deaths                           1076
# New recovered                       33728
# Deaths / 100 Cases                  28.56
# Recovered / 100 Cases               100.0
# Deaths / 100 Recovered                inf
# Confirmed last week               3834677
# 1 week change                      455582
# 1 week % increase                  226.32
# WHO Region                Western Pacific
# dtype: object

# %% [markdown]
# **sameway country with least deaths.**

# %%
covid.min()
# Out:
# Country/Region            Afghanistan
# Confirmed                          10
# Deaths                              0
# Recovered                           0
# Active                              0
# New cases                           0
# New deaths                          0
# New recovered                       0
# Deaths / 100 Cases                0.0
# Recovered / 100 Cases             0.0
# Deaths / 100 Recovered            0.0
# Confirmed last week                10
# 1 week change                     -47
# 1 week % increase               -3.84
# WHO Region                     Africa
# dtype: object

# %% [markdown]
# **Describing Data**

# %%
covid.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %% [markdown]
# **lets visualize the top 20 countriees**

# %%
plt.figure(figsize=(10,15))
covid['Country/Region'].head(20).value_counts().plot.pie(autopct="%1.1f%%")     #Note use of pie diagram.
plt.title('Top 20 Country With Max Cases',fontsize=9)                         #Note Labelling of diagram
plt.ylabel('Countries',fontsize=10)
plt.show()

# %% [markdown]
# **visualizing top confirmed cases by country**

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(15,10))
sns.countplot(data=covid.head(20),y='Confirmed')                    #Note here we are using countplot as sns which is an in-nuilt library in python that uses mtplotlib underneath to plot graphs.
plt.xticks(rotation='vertical')                                    #Note use of ticks for a better view of diagram.
plt.title('Top Confirmed Cases By Country',fontsize=25)            #Note labelling the data
plt.xlabel('Confirmed Cases')                               
plt.show()

# %% [markdown]
# **now visualizing top 20 record countries**

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(15,10))
sns.countplot(data=covid.head(20),y='Confirmed')                    #Note here we are using countplot as sns which is an in-nuilt library in python that uses mtplotlib underneath to plot graphs.
plt.xticks(rotation='vertical')                                    #Note use of ticks for a better view of diagram.
plt.title('Top Confirmed Cases By Country',fontsize=25)            #Note labelling the data
plt.xlabel('Confirmed Cases')                               
plt.show()

# %% [markdown]
# **top 20 Deaths by countries**

# %%
plt.figure(figsize=(10,15))       #Note the figure size
covid['Deaths'].head(20).value_counts().plot.pie(autopct="%1.1f%%")    #Note use of pie plot
plt.title('Top 20 Deaths With Countries',fontsize=25)                 #Note leabelling the diagram
plt.xlabel('Countries',fontsize=15)
plt.show()

# %% [markdown]
# **SUMMARY**

# %% [markdown]
# **The COVID-19 data analysis revealed crucial insights into the pandemic's impact. The analysis examined overall case numbers, regional distribution, temporal trends, demographic factors, testing and reporting practices, vaccination impact, and policy effectiveness. These findings provide a comprehensive understanding of the pandemic's impact and can guide effective public health strategies and decision-making to mitigate the spread of the virus.**
